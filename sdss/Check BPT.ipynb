# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

lx = np.arange(1500)*0.001 - 1.5
ly = 0.61/(lx-0.47) + 1.19
plt.figure()
plt.xlim((-2.4, 0))
plt.ylim((-1.2, 1))
plt.plot(lx, ly)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
lx = np.arange(1500)*0.001 - 1.5
ly = 0.72/(lx-0.32) + 1.30
plt.figure()
plt.xlim((-1.5, 0.5))
plt.ylim((-1.2, 1))
plt.plot(lx, ly)

# data point for SN2009nz
x4 = -0.564271
y4 = 0.596597
plt.plot(x4, y4, 'ro')
# Out:
# <img src="data:image/png;base64,..." width="640">
